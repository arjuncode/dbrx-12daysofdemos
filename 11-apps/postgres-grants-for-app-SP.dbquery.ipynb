-- %%
-- Replace recipient of grants to your App's Service principal ID, found in the Authorization tab of the App
GRANT CONNECT ON DATABASE databricks_postgres TO "50496e18-3f29-4e51-9f02-f801bbdc902f";
GRANT USAGE, CREATE ON SCHEMA public TO "50496e18-3f29-4e51-9f02-f801bbdc902f";
GRANT ALL PRIVILEGES ON TABLE "databricks_postgres"."public"."gift_requests_synced_table" TO "50496e18-3f29-4e51-9f02-f801bbdc902f";
